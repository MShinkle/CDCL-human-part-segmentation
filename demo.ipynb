# %%
import h5py
import cv2
from cdcl.wrapper import CDCL_process
from cdcl.viz import show_parts_overlay
from matplotlib import pyplot as plt
import numpy as np

# %matplotlib inline

process = CDCL_process()
image_filepath = "D:/stimuli/NaturalMovies/images/val/im0000033.png"
img = plt.imread(image_filepath)
parts = process.extract_parts(img, target_size=[15,15], scales=[1.0], verbose=False, input_rgb=True)
show_parts_overlay(parts[0], image_filepath)
# Out:
# c:\Users\matth\anaconda3\envs\cdcl\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
